# %% [markdown]
# # Airbnb Sicilia
# ## *Review of Sicilian Airbnb hosts and listings*
#
#
# #### Datasources:
# - Main website link: https://www.airbnb.com/
#
# This repository contains the code developed for the Udacity Data Scientist Nanodegree [nanodegree](https://www.udacity.com/courses/data-scientist-nanodegree--nd025). It's written in **Python Jupyter Notebooks**.
#
# The code focuses on data cleaning and a simple linear model for prediction of the number of reviews (that we will consider a representation of the number of sales.
#
# The statistical prediction is limited by the available features as well as by the employment of Ordinary Least Square Multiple Linear Regression.
#
# The outcome is anyway of some interest as, in its simplicity, it is able to predict the data variability up to R2 = 0.57 and shows which features have statistical significance.
#
#
# ## Description
#
# Airbnb, Inc. is an American company that operates an online marketplace for lodging, primarily homestays for vacation rentals, and tourism activities. Based in San Francisco, California, the platform is accessible via website and mobile app ([source](https://en.wikipedia.org/wiki/Airbnb)).
#
# In Sicily, Airbnb publishes 51,000+ listings. The vast majority is for entire homes or apartments, the rest is for private rooms. Some top level analysis can be found here: http://insideairbnb.com/sicily
#
# The Sicilian coast line is densily populated, as well as some internal areas, especially during the summer period. It is quite common to own a holiday house. During the past few years, pushed by increasing taxes on property, economic depression and the increased availability of listing platforms on the internet (see Booking.com, Airbnb.com, etc) it is more and more common to rent those properties as a form of secondary income.
#
# Considering Sicily is a big tourism attraction (more than 2 millions bookings in 2021, https://www.guidasicilia.it/notizia/nel-2021-la-sicilia-ha-trainato-il-turismo-italiano/3014341) it is clear there are a large number of hosts for whom tourist is the main form of business.
#
# ## Data
#
# - http://insideairbnb.com/sicily
# - http://data.insideairbnb.com/italy/sicilia/sicily/2022-03-29/data/listings.csv.gz
#
# Data are those freely made available on the InsideAirbnb website.
#
# ## Main Ideas
#
# 1. The provided datasets have lot of missing values and some other which are difficult to interpret or use.
# Most of the efforts of this notebook are on pre-processing.
#     - Replace NaNs with known values (zeros or means)
#     - Clean various features
#     - Identify key features for the prediction
#
#
# 2. We will not consider any geographical feature (such as neighborhood or latitude/longitude) as it would have required additional effort to reduce the neighborhood number of variables based on geographical or administrative categorization (area, county etc).
#
#
# ## Requirements
#
# To replicate the findings and execute the code in this repository you will need
# basically the next Python packages:
#
# - [NumPy](http://www.numpy.org/)
# - [Pandas](http://pandas.pydata.org/)
# - [Jupyter](http://jupyter.org/)
# - [SciKit-Learn](http://scikit-learn.org/stable/)
# - [Matplotlib](http://matplotlib.org/)
#
#
# ## Author
#
# 2022-Aug, Saverio Tufano
